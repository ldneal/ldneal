# %% [markdown]
# # Importing Dependencies

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from keras_tuner.tuners import RandomSearch
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_squared_log_error, r2_score
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# # Getting Data and it's information

# %%
dataset = pd.read_csv('Housing Prices Dataset.csv')

# %%
dataset.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
dataset.shape
# Out:
# (545, 13)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    object
#  6   guestroom         545 non-null    object
#  7   basement          545 non-null    object
#  8   hotwaterheating   545 non-null    object
#  9   airconditioning   545 non-null    object
#  10  parking           545 non-null    int64
#  11  prefarea          545 non-null    object
#  12  furnishingstatus  545 non-null    object
# dtypes: int64(6), object(7)
# memory usage: 55.5+ KB

# %%
dataset.describe()
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#           parking
# count  545.000000
# mean     0.693578
# std      0.861586
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %% [markdown]
# # Visualising Dataset

# %%
# Plot the distribution of Price
plt.figure(figsize=(10, 6))
sns.histplot(dataset['price'], kde=True)
plt.title('Distribution of Price')
plt.xlabel('Price')
plt.ylabel('Count')
plt.show()

# %%
# Understanding Relationship between Numerical Columns
sns.pairplot(dataset[['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'parking']])
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.countplot(x='airconditioning', data=dataset)
plt.title('Counts of Air Conditioning')
plt.xlabel('Air Conditioning')
plt.ylabel('Count')
plt.show()

# %%
 # Relationship between 2 features
plt.figure(figsize=(10, 6))
sns.boxplot(x='bedrooms', y='price', data=dataset)
plt.title('Price by Bedrooms')
plt.xlabel('Bedrooms')
plt.ylabel('Price')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='furnishingstatus', data=dataset)
plt.title('Counts of Furnishing Status')
plt.xlabel('Furnishing Status')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %%
# Example for 'prefarea' variable
plt.figure(figsize=(8, 5))
sns.countplot(x='prefarea', data=dataset)
plt.title('Counts of Preferred Area')
plt.xlabel('Preferred Area')
plt.ylabel('Count')
plt.show()

# %%
# Example: Boxplot for 'price' by 'mainroad'
plt.figure(figsize=(10, 6))
sns.boxplot(x='mainroad', y='price', data=dataset)
plt.title('Price by Mainroad')
plt.xlabel('Mainroad')
plt.ylabel('Price')
plt.show()

# %%
# Example for 'area' variable
plt.figure(figsize=(10, 6))
sns.histplot(dataset['area'], kde=True, color='green')
plt.title('Distribution of Area')
plt.xlabel('Area')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# # Converting Categorical Columns

# %%
encoded_data = pd.get_dummies( dataset,columns=['mainroad','guestroom','basement','hotwaterheating','airconditioning','prefarea','furnishingstatus'])
encoded_data.columns
# Out:
# Index(['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'parking',
#        'mainroad_no', 'mainroad_yes', 'guestroom_no', 'guestroom_yes',
#        'basement_no', 'basement_yes', 'hotwaterheating_no',
#        'hotwaterheating_yes', 'airconditioning_no', 'airconditioning_yes',
#        'prefarea_no', 'prefarea_yes', 'furnishingstatus_furnished',
#        'furnishingstatus_semi-furnished', 'furnishingstatus_unfurnished'],
#       dtype='object')

# %% [markdown]
# # Understanding Correlation

# %%
sns.heatmap(encoded_data.corr(), cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
encoded_data.shape
# Out:
# (545, 21)

# %%
encoded_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 21 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   price                            545 non-null    int64
#  1   area                             545 non-null    int64
#  2   bedrooms                         545 non-null    int64
#  3   bathrooms                        545 non-null    int64
#  4   stories                          545 non-null    int64
#  5   parking                          545 non-null    int64
#  6   mainroad_no                      545 non-null    bool
#  7   mainroad_yes                     545 non-null    bool
#  8   guestroom_no                     545 non-null    bool
#  9   guestroom_yes                    545 non-null    bool
#  10  basement_no                      545 non-null    bool
#  11  basement_yes                     545 non-null    bool
#  12  hotwaterheating_no               545 non-null    bool
#  13  hotwaterheating_yes              545 non-null    bool
#  14  airconditioning_no               545 non-null    bool
#  15  airconditioning_yes              545 non-null    bool
#  16  prefarea_no                      545 non-null    bool
#  17  prefarea_yes                     545 non-null    bool
#  18  furnishingstatus_furnished       545 non-null    bool
#  19  furnishingstatus_semi-furnished  545 non-null    bool
#  20  furnishingstatus_unfurnished     545 non-null    bool
# dtypes: bool(15), int64(6)
# memory usage: 33.7 KB

# %% [markdown]
# # Dividing Target and Features

# %%
X = encoded_data.drop(['price'],axis=1)
Y = encoded_data['price']

# %% [markdown]
# # Feature Scaling

# %%
sc = StandardScaler()
X_scaled = sc.fit_transform(X)

# %% [markdown]
# # Using Train Test Split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X_scaled, Y,
test_size=0.2, random_state=100)

# %% [markdown]
# # Model Building

# %%
def build_model(hp):
    model = keras.Sequential()
    model.add(layers.Input(shape=(20,)))

    hp_units1 = hp.Int('units1', min_value=32, max_value=512, step=32)
    hp_activation1 = hp.Choice('activation1', values=['relu', 'tanh', 'sigmoid'])

    model.add(layers.Dense(units=hp_units1, activation=hp_activation1))

    hp_units2 = hp.Int('units2', min_value=32, max_value=512, step=32)
    hp_activation2 = hp.Choice('activation2', values=['relu', 'tanh', 'sigmoid'])

    model.add(layers.Dense(units=hp_units2, activation=hp_activation2))

    model.add(layers.Dense(1, activation='linear'))  

    hp_learning_rate = hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])

    model.compile(optimizer=keras.optimizers.Adam(learning_rate=hp_learning_rate),
                  loss='mean_squared_error',
                  metrics=['mean_absolute_error'])

    return model

# %% [markdown]
# # Hyperparameter Tuning

# %%
tuner = RandomSearch(
    build_model,
    objective='val_loss',
    max_trials=10,
    executions_per_trial=3,
    directory='my_dir',
    project_name='my_project'
)

# %%
tuner.search(X_train, Y_train, validation_data=(X_test, Y_test), epochs=10)
# Out:
# Trial 10 Complete [00h 00m 04s]
# val_loss: 25155835964074.668
#
# Best val_loss So Far: 25153618575360.0
# Total elapsed time: 00h 00m 44s

# %%
tuner.results_summary()
# Out:
# Results summary
# Results in my_dir/my_project
# Showing 10 best trials
# Objective(name="val_loss", direction="min")
#
# Trial 01 summary
# Hyperparameters:
# units1: 352
# activation1: tanh
# units2: 416
# activation2: sigmoid
# learning_rate: 0.01
# Score: 25153618575360.0
#
# Trial 08 summary
# Hyperparameters:
# units1: 32
# activation1: tanh
# units2: 448
# activation2: tanh
# learning_rate: 0.01
# Score: 25153698966186.668
#
# Trial 02 summary
# Hyperparameters:
# units1: 96
# activation1: tanh
# units2: 480
# activation2: relu
# learning_rate: 0.001
# Score: 25154218360832.0
#
# Trial 09 summary
# Hyperparameters:
# units1: 320
# activation1: sigmoid
# units2: 96
# activation2: relu
# learning_rate: 0.001
# Score: 25155835964074.668
#
# Trial 03 summary
# Hyperparameters:
# units1: 64
# activation1: sigmoid
# units2: 128
# activation2: tanh
# learning_rate: 0.01
# Score: 25156950250837.332
#
# Trial 04 summary
# Hyperparameters:
# units1: 224
# activation1: sigmoid
# units2: 224
# activation2: sigmoid
# learning_rate: 0.01
# Score: 25157043224576.0
#
# Trial 05 summary
# Hyperparameters:
# units1: 320
# activation1: sigmoid
# units2: 416
# activation2: relu
# learning_rate: 0.0001
# Score: 25158484667050.668
#
# Trial 06 summary
# Hyperparameters:
# units1: 480
# activation1: sigmoid
# units2: 32
# activation2: sigmoid
# learning_rate: 0.01
# Score: 25158520318634.668
#
# Trial 07 summary
# Hyperparameters:
# units1: 160
# activation1: relu
# units2: 448
# activation2: sigmoid
# learning_rate: 0.0001
# Score: 25158705567061.332
#
# Trial 00 summary
# Hyperparameters:
# units1: 416
# activation1: tanh
# units2: 320
# activation2: relu
# learning_rate: 0.0001
# Score: 25158707664213.332

# %% [markdown]
# # Retraining Model

# %%
# Get the best model
best_model = tuner.get_best_models(num_models=1)[0]

# Train the best model
best_model.fit(X_train, Y_train, epochs=50, validation_data=(X_test, Y_test))
# Out:
# Epoch 1/50
# 14/14 [==============================] - 1s 11ms/step - loss: 26471926071296.0000 - mean_absolute_error: 4795164.0000 - val_loss: 25153090093056.0000 - val_mean_absolute_error: 4650147.0000
# Epoch 2/50
# 14/14 [==============================] - 0s 4ms/step - loss: 26471389200384.0000 - mean_absolute_error: 4795111.0000 - val_loss: 25152588873728.0000 - val_mean_absolute_error: 4650095.5000
# Epoch 3/50
# 14/14 [==============================] - 0s 4ms/step - loss: 26470860718080.0000 - mean_absolute_error: 4795058.0000 - val_loss: 25152091848704.0000 - val_mean_absolute_error: 4650044.0000
# Epoch 4/50
# 14/14 [==============================] - 0s 4ms/step - loss: 26470336430080.0000 - mean_absolute_error: 4795006.0000 - val_loss: 25151592726528.0000 - val_mean_absolute_error: 4649993.5000
# Epoch 5/50
# 14/14 [==============================] - 0s 4ms/step - loss: 26469812142080.0000 - mean_absolute_error: 4794953.5000 - val_loss: 25151093604352.0000 - val_mean_absolute_error: 4649942.5000
# Epoch 6/50
# 14/14 [==============================] - 0s 4ms/step - loss: 26469289951232.0000 - mean_absolute_error: 4794901.0000 - val_loss: 25150596579328.0000 - val_mean_absolute_error: 4649891.0000
# Epoch 7/50
# 14/14 [==============================] - 0s 4ms/step - loss: 26468769857536.0000 - mean_absolute_error: 4794849.0000 - val_loss: 25150103748608.0000 - val_mean_absolute_error: 4649840.5000
# Epoch 8/50
# 14/14 [==============================] - 0s 4ms/step - loss: 26468243472384.0000 - mean_absolute_error: 4794798.0000 - val_loss: 25149613015040.0000 - val_mean_absolute_error: 4649790.0000
# Epoch 9/50
# 14/14 [==============================] - 0s 4ms/step - loss: 26467731767296.0000 - mean_absolute_error: 4794746.5000 - val_loss: 25149111795712.0000 - val_mean_absolute_error: 4649739.0000
# Epoch 10/50
# 14/14 [==============================] - 0s 4ms/step - loss: 26467213770752.0000 - mean_absolute_error: 4794695.0000 - val_loss: 25148616867840.0000 - val_mean_absolute_error: 4649687.5000
# Epoch 11/50
# 14/14 [==============================] - 0s 4ms/step - loss: 26466687385600.0000 - mean_absolute_error: 4794642.0000 - val_loss: 25148134522880.0000 - val_mean_absolute_error: 4649638.0000
# Epoch 12/50
# 14/14 [==============================] - 0s 4ms/step - loss: 26466173583360.0000 - mean_absolute_error: 4794591.5000 - val_loss: 25147645886464.0000 - val_mean_absolute_error: 4649589.0000
# Epoch 13/50
# 14/14 [==============================] - 0s 4ms/step - loss: 26465661878272.0000 - mean_absolute_error: 4794540.5000 - val_loss: 25147157250048.0000 - val_mean_absolute_error: 4649538.0000
# Epoch 14/50
# 14/14 [==============================] - 0s 5ms/step - loss: 26465148076032.0000 - mean_absolute_error: 4794488.5000 - val_loss: 25146664419328.0000 - val_mean_absolute_error: 4649487.5000
# Epoch 15/50
# 14/14 [==============================] - 0s 4ms/step - loss: 26464625885184.0000 - mean_absolute_error: 4794437.5000 - val_loss: 25146175782912.0000 - val_mean_absolute_error: 4649437.5000
# Epoch 16/50
# 14/14 [==============================] - 0s 4ms/step - loss: 26464114180096.0000 - mean_absolute_error: 4794385.5000 - val_loss: 25145687146496.0000 - val_mean_absolute_error: 4649387.5000
# Epoch 17/50
# 14/14 [==============================] - 0s 4ms/step - loss: 26463606669312.0000 - mean_absolute_error: 4794335.0000 - val_loss: 25145196412928.0000 - val_mean_absolute_error: 4649336.5000
# Epoch 18/50
# 14/14 [==============================] - 0s 4ms/step - loss: 26463088672768.0000 - mean_absolute_error: 4794284.0000 - val_loss: 25144711970816.0000 - val_mean_absolute_error: 4649287.0000
# Epoch 19/50
# 14/14 [==============================] - 0s 4ms/step - loss: 26462576967680.0000 - mean_absolute_error: 4794232.5000 - val_loss: 25144223334400.0000 - val_mean_absolute_error: 4649236.5000
# Epoch 20/50
# 14/14 [==============================] - 0s 4ms/step - loss: 26462065262592.0000 - mean_absolute_error: 4794181.5000 - val_loss: 25143738892288.0000 - val_mean_absolute_error: 4649187.0000
# Epoch 21/50
# 14/14 [==============================] - 0s 3ms/step - loss: 26461553557504.0000 - mean_absolute_error: 4794131.0000 - val_loss: 25143250255872.0000 - val_mean_absolute_error: 4649137.0000
# Epoch 22/50
# 14/14 [==============================] - 0s 4ms/step - loss: 26461043949568.0000 - mean_absolute_error: 4794080.0000 - val_loss: 25142761619456.0000 - val_mean_absolute_error: 4649087.0000
# Epoch 23/50
# 14/14 [==============================] - 0s 4ms/step - loss: 26460532244480.0000 - mean_absolute_error: 4794029.0000 - val_loss: 25142285565952.0000 - val_mean_absolute_error: 4649038.0000
# Epoch 24/50
# 14/14 [==============================] - 0s 4ms/step - loss: 26460022636544.0000 - mean_absolute_error: 4793978.0000 - val_loss: 25141796929536.0000 - val_mean_absolute_error: 4648988.0000
# Epoch 25/50
# 14/14 [==============================] - 0s 4ms/step - loss: 26459510931456.0000 - mean_absolute_error: 4793927.5000 - val_loss: 25141314584576.0000 - val_mean_absolute_error: 4648938.5000
# Epoch 26/50
# 14/14 [==============================] - 0s 4ms/step - loss: 26459009712128.0000 - mean_absolute_error: 4793877.0000 - val_loss: 25140830142464.0000 - val_mean_absolute_error: 4648889.0000
# Epoch 27/50
# 14/14 [==============================] - 0s 4ms/step - loss: 26458491715584.0000 - mean_absolute_error: 4793825.5000 - val_loss: 25140347797504.0000 - val_mean_absolute_error: 4648839.0000
# Epoch 28/50
# 14/14 [==============================] - 0s 4ms/step - loss: 26457982107648.0000 - mean_absolute_error: 4793775.0000 - val_loss: 25139869646848.0000 - val_mean_absolute_error: 4648790.5000
# Epoch 29/50
# 14/14 [==============================] - 0s 4ms/step - loss: 26457476694016.0000 - mean_absolute_error: 4793724.0000 - val_loss: 25139387301888.0000 - val_mean_absolute_error: 4648740.0000
# Epoch 30/50
# 14/14 [==============================] - 0s 4ms/step - loss: 26456969183232.0000 - mean_absolute_error: 4793674.5000 - val_loss: 25138898665472.0000 - val_mean_absolute_error: 4648691.0000
# Epoch 31/50
# 14/14 [==============================] - 0s 4ms/step - loss: 26456459575296.0000 - mean_absolute_error: 4793623.0000 - val_loss: 25138412126208.0000 - val_mean_absolute_error: 4648640.5000
# Epoch 32/50
# 14/14 [==============================] - 0s 4ms/step - loss: 26455943675904.0000 - mean_absolute_error: 4793572.0000 - val_loss: 25137929781248.0000 - val_mean_absolute_error: 4648590.5000
# Epoch 33/50
# 14/14 [==============================] - 0s 4ms/step - loss: 26455440359424.0000 - mean_absolute_error: 4793520.5000 - val_loss: 25137443241984.0000 - val_mean_absolute_error: 4648541.0000
# Epoch 34/50
# 14/14 [==============================] - 0s 4ms/step - loss: 26454924460032.0000 - mean_absolute_error: 4793470.0000 - val_loss: 25136962994176.0000 - val_mean_absolute_error: 4648491.5000
# Epoch 35/50
# 14/14 [==============================] - 0s 4ms/step - loss: 26454419046400.0000 - mean_absolute_error: 4793420.0000 - val_loss: 25136480649216.0000 - val_mean_absolute_error: 4648442.0000
# Epoch 36/50
# 14/14 [==============================] - 0s 5ms/step - loss: 26453915729920.0000 - mean_absolute_error: 4793369.5000 - val_loss: 25136000401408.0000 - val_mean_absolute_error: 4648392.5000
# Epoch 37/50
# 14/14 [==============================] - 0s 4ms/step - loss: 26453412413440.0000 - mean_absolute_error: 4793319.0000 - val_loss: 25135513862144.0000 - val_mean_absolute_error: 4648342.5000
# Epoch 38/50
# 14/14 [==============================] - 0s 4ms/step - loss: 26452898611200.0000 - mean_absolute_error: 4793267.5000 - val_loss: 25135029420032.0000 - val_mean_absolute_error: 4648293.5000
# Epoch 39/50
# 14/14 [==============================] - 0s 4ms/step - loss: 26452389003264.0000 - mean_absolute_error: 4793218.0000 - val_loss: 25134549172224.0000 - val_mean_absolute_error: 4648244.5000
# Epoch 40/50
# 14/14 [==============================] - 0s 4ms/step - loss: 26451887783936.0000 - mean_absolute_error: 4793167.5000 - val_loss: 25134066827264.0000 - val_mean_absolute_error: 4648194.5000
# Epoch 41/50
# 14/14 [==============================] - 0s 4ms/step - loss: 26451373981696.0000 - mean_absolute_error: 4793117.0000 - val_loss: 25133592870912.0000 - val_mean_absolute_error: 4648145.5000
# Epoch 42/50
# 14/14 [==============================] - 0s 4ms/step - loss: 26450872762368.0000 - mean_absolute_error: 4793066.5000 - val_loss: 25133106331648.0000 - val_mean_absolute_error: 4648095.5000
# Epoch 43/50
# 14/14 [==============================] - 0s 4ms/step - loss: 26450361057280.0000 - mean_absolute_error: 4793016.0000 - val_loss: 25132632375296.0000 - val_mean_absolute_error: 4648046.5000
# Epoch 44/50
# 14/14 [==============================] - 0s 4ms/step - loss: 26449855643648.0000 - mean_absolute_error: 4792965.5000 - val_loss: 25132152127488.0000 - val_mean_absolute_error: 4647998.0000
# Epoch 45/50
# 14/14 [==============================] - 0s 4ms/step - loss: 26449350230016.0000 - mean_absolute_error: 4792916.0000 - val_loss: 25131665588224.0000 - val_mean_absolute_error: 4647947.5000
# Epoch 46/50
# 14/14 [==============================] - 0s 4ms/step - loss: 26448846913536.0000 - mean_absolute_error: 4792864.5000 - val_loss: 25131181146112.0000 - val_mean_absolute_error: 4647898.0000
# Epoch 47/50
# 14/14 [==============================] - 0s 4ms/step - loss: 26448337305600.0000 - mean_absolute_error: 4792814.0000 - val_loss: 25130702995456.0000 - val_mean_absolute_error: 4647849.0000
# Epoch 48/50
# 14/14 [==============================] - 0s 4ms/step - loss: 26447829794816.0000 - mean_absolute_error: 4792762.5000 - val_loss: 25130222747648.0000 - val_mean_absolute_error: 4647799.5000
# Epoch 49/50
# 14/14 [==============================] - 0s 4ms/step - loss: 26447326478336.0000 - mean_absolute_error: 4792713.5000 - val_loss: 25129738305536.0000 - val_mean_absolute_error: 4647749.5000
# Epoch 50/50
# 14/14 [==============================] - 0s 4ms/step - loss: 26446816870400.0000 - mean_absolute_error: 4792662.5000 - val_loss: 25129260154880.0000 - val_mean_absolute_error: 4647700.5000

# %% [markdown]
# # Evaluation Metrices

# %%
y_pred = best_model.predict(X_test)
y_pred = (y_pred > 0.5)
# Calculate Mean Absolute Error (MAE)
mae = mean_absolute_error(Y_test, y_pred)
print(f'MAE: {mae}')

# Calculate Mean Squared Error (MSE)
mse = mean_squared_error(Y_test, y_pred)
print(f'MSE: {mse}')

# Calculate Root Mean Squared Error (RMSE)
rmse = mean_squared_error(Y_test, y_pred, squared=False)
print(f'RMSE: {rmse}')

# Calculate Root Mean Squared Logarithmic Error (RMSLE)
rmsle = mean_squared_log_error(Y_test, y_pred, squared=False)
print(f'RMSLE: {rmsle}')

# Calculate R-squared (Coefficient of Determination)
r2 = r2_score(Y_test, y_pred)
print(f'R-squared (R2): {r2}')
# Out:
# 4/4 [==============================] - 0s 1ms/step
# MAE: 4650728.357798165
# MSE: 25158755127441.367
# RMSE: 5015850.389260167
# RMSLE: 14.587722738763139
# R-squared (R2): -6.128174385493444
